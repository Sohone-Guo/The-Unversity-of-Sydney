# %%
import requests
import re


url = "http://www.myhuiban.com/conference"
get_signal = requests.get(url).text
get_signal
# Out:
# '\n<!DOCTYPE html>\n<html lang="en">\n  <head>\n    <meta charset="utf-8">\n    <link rel="stylesheet" type="text/css" href="/themes/abound/css/bootstrap.min.css" />\n<link rel="stylesheet" type="text/css" href="/themes/abound/css/bootstrap-responsive.min.css" />\n<link rel="stylesheet" type="text/css" href="/themes/abound/css/abound.css" />\n<link rel="stylesheet" type="text/css" href="/themes/abound/css/style-orange.css" />\n<script type="text/javascript" src="/assets/19c2ef74/jquery.min.js"></script>\n<script type="text/javascript" src="/assets/19c2ef74/jquery.yiiactiveform.js"></script>\n<script type="text/javascript" src="/themes/abound/js/bootstrap.min.js"></script>\n<script type="text/javascript" src="/themes/abound/js/plugins/jquery.flot.min.js"></script>\n<title>Login - Conference Partner</title>\n    <meta name="viewport" content="width=device-width, initial-scale=1.0">\n    <meta name="description" content="The Latest Computer Conference and Journal List">\n    <meta name=
# ...

# %%
url = "http://www.myhuiban.com/conference/"
get_signal = requests.get(url).text
get_signal
# Out:
# '\n<!DOCTYPE html>\n<html lang="en">\n  <head>\n    <meta charset="utf-8">\n    <link rel="stylesheet" type="text/css" href="/themes/abound/css/bootstrap.min.css" />\n<link rel="stylesheet" type="text/css" href="/themes/abound/css/bootstrap-responsive.min.css" />\n<link rel="stylesheet" type="text/css" href="/themes/abound/css/abound.css" />\n<link rel="stylesheet" type="text/css" href="/themes/abound/css/style-orange.css" />\n<script type="text/javascript" src="/assets/19c2ef74/jquery.min.js"></script>\n<script type="text/javascript" src="/assets/19c2ef74/jquery.yiiactiveform.js"></script>\n<script type="text/javascript" src="/themes/abound/js/bootstrap.min.js"></script>\n<script type="text/javascript" src="/themes/abound/js/plugins/jquery.flot.min.js"></script>\n<title>Login - Conference Partner</title>\n    <meta name="viewport" content="width=device-width, initial-scale=1.0">\n    <meta name="description" content="The Latest Computer Conference and Journal List">\n    <meta name=
# ...

# %%
import requests
s = requests.session()
data = {'LoginForm[email]':'878153077@qq.com','LoginForm[password]':'fancheng901125'}
s.post('https://www.myhuiban.com/login',data)
# r = s.get("http://www.myhuiban.com/conference/")http://www.myhuiban.com/journals
# r.text
s.get("http://www.myhuiban.com/conferences").text
# Out:
# '\n<!DOCTYPE html>\n<html lang="en">\n  <head>\n    <meta charset="utf-8">\n    <link rel="stylesheet" type="text/css" href="/assets/23c1269/gridview/styles.css" />\n<link rel="stylesheet" type="text/css" href="/themes/abound/css/bootstrap.min.css" />\n<link rel="stylesheet" type="text/css" href="/themes/abound/css/bootstrap-responsive.min.css" />\n<link rel="stylesheet" type="text/css" href="/themes/abound/css/abound.css" />\n<link rel="stylesheet" type="text/css" href="/themes/abound/css/style-orange.css" />\n<script type="text/javascript" src="/assets/19c2ef74/jquery.min.js"></script>\n<script type="text/javascript" src="/assets/19c2ef74/jquery.ba-bbq.min.js"></script>\n<script type="text/javascript" src="/themes/abound/js/bootstrap.min.js"></script>\n<script type="text/javascript" src="/themes/abound/js/plugins/jquery.flot.min.js"></script>\n<title>Error - Conference Partner</title>\n    <meta name="viewport" content="width=device-width, initial-scale=1.0">\n    <meta name="descr
# ...

# %%
s.get("http://www.myhuiban.com/conference/2349").text
# Out:
# '\n<!DOCTYPE html>\n<html lang="en">\n  <head>\n    <meta charset="utf-8">\n    <link rel="stylesheet" type="text/css" href="/assets/23c1269/gridview/styles.css" />\n<link rel="stylesheet" type="text/css" href="/themes/abound/css/bootstrap.min.css" />\n<link rel="stylesheet" type="text/css" href="/themes/abound/css/bootstrap-responsive.min.css" />\n<link rel="stylesheet" type="text/css" href="/themes/abound/css/abound.css" />\n<link rel="stylesheet" type="text/css" href="/themes/abound/css/style-orange.css" />\n<script type="text/javascript" src="/assets/19c2ef74/jquery.min.js"></script>\n<script type="text/javascript" src="/assets/19c2ef74/jquery.ba-bbq.min.js"></script>\n<script type="text/javascript" src="/themes/abound/js/bootstrap.min.js"></script>\n<script type="text/javascript" src="/themes/abound/js/plugins/jquery.flot.min.js"></script>\n<title>ICIIT 2017 : International conference on Intelligent Information Technologies</title>\n    <meta name="viewport" content="width=devic
# ...

# %%
import urllib

ponse = urllib.urlopen("http://www.myhuiban.com/journals")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-95ea08da2877> in <module>()
#       3 import urllib
#       4
# ----> 5 ponse = urllib.urlopen("http://www.myhuiban.com/journals")
#       6
#
# AttributeError: module 'urllib' has no attribute 'urlopen'
